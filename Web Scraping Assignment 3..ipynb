# %% [markdown]
# ### 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
from selenium import webdriver
import pandas as pd
import time
import requests
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.amazon.in/')
#Giving input
search_item= input('Enter the product that has to be searched : ')
# Out:
# Enter the product that has to be searched : laptop

# %%
#Scraping search bar Xpath and clicking on search icon
search_bar = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')                                                  
search_bar.send_keys(search_item)

# %%
search_button = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

# %% [markdown]
# #### 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#collecting all the Product URLS here
urls = []
for i in range(0,3):
    Page_urls=driver.find_elements(By.XPATH,"//a[@class='a-link-normal s-no-outline']")#collecting urls of all the laptop
    for i in Page_urls:
        urls.append(i.get_attribute('href'))

# %%
#next button 
nxt_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[28]/div/div/span/a[3]')   #scraping the list of buttons from the page
url=nxt_button.get_attribute('href')
driver.get(url)
time.sleep(2)

# %%
#Making empty lists and scraping the required spots
Product_name = []
Brand_name= []
Price = []
Return = []
Expected_Delivery = []
Availability = []

#Start with for loop
for i in urls:
    driver.get(i)
    time.sleep(10)
    
    
    #Scraping data for product name
    try:
        prod=driver.find_element(By.XPATH,"//span[@id='productTitle']")
        Product_name.append(prod.text)
    except NoSuchElementException as e:
        Product_name.append("-")
        
        
    #Scraping data for brand name
    try:
        brand=driver.find_element(By.XPATH,"//div[@id='bylineInfo_feature_div']/div/a")
        Brand_name.append(brand.text)
    except NoSuchElementException as e:
        Brand_name.append("-")
        
         
    #Scraping data for Price
    try:
        pri=driver.find_element(By.XPATH,"//span[@id='a-price-whole']")
        Price.append(pri.text)
    except NoSuchElementException as e:
        Price.append("-")
        
        
    #Scraping data for Return/Exchange
    try:
        ret=driver.find_element(By.XPATH,"//div[@class='a-section a-spacing-none icon-content']")
        Return.append(ret.text)
    except NoSuchElementException as e:
        Return.append("-")
        
     
    #Scraping data for Expected_Delivary
    try:
        delivary=driver.find_element(By.XPATH,"//a[@class='a-size-small a-link-normal a-text-normal']")
        Expected_Delivery.append(delivary.text)
    except NoSuchElementException as e:
        Expected_Delivery.append("-")
        
        
    #Scraping data for Availability
    try:
        avai=driver.find_element(By.XPATH,"//div[@id='availability']/span")
        Availability.append(avai.text)
    except NoSuchElementException as e:
        Availability.append("-")
        
# here  due   to code  rerunning  which  will take much  time   so   iam  removing  cell  output

# %%
Laptop=pd.DataFrame({})
Laptop['Name'] = Product_name
Laptop['Brand'] = Brand_name
Laptop['Return/exchange'] =Return
Laptop['Availability'] = Availability
Laptop['Expected_delievery']=Expected_Delivery
Laptop['Url']=urls
Laptop
# Out:
#                                                  Name                   Brand  \
# 0   LG Gram 17 Intel 10th Gen i7 Thin & Light Lapt...      Visit the LG Store
# 1   ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD...    Visit the ASUS Store
# 2   ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...    Visit the ASUS Store
# 3   Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...    Visit the Dell Store
# 4   Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...  Visit the Lenovo Store
# ..                                                ...                     ...
# 61  Redmi Book 15 Intel Core I3 11Th Gen/8 Gb/256 ...            Brand: Redmi
# 62  Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" FHD T...  Visit the Lenovo Store
# 63  Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen...  Visit the Lenovo Store
# 64  Hp Victus Latest AMD Ryzen 5 5600H Processor 1...      Visit the HP Store
# 65  Lenovo Ideapad Slim 5 Pro AMD Ryzen 7 5800U 14...  Visit the Lenovo Store
#
#        Return/exchange            Availability  Expected_delievery  \
# 0   7 Days Replacement  Sale starts on July 22  7 Days Replacement
# 1   7 Days Replacement               In stock.  7 Days Replacement
# 2      Pay on Delivery               In stock.     Pay on Delivery
# 3   7 Days Replacement               In stock.  7 Days Replacement
# 4      Pay on Delivery               In stock.     Pay on Delivery
# ..                 ...                     ...                 ...
# 61  7 Days Replacement               In stock.  7 Days Replacement
# 62  7 Days Replacement               In stock.  7 Days Replacement
# 63  7 Days Replacement                          7 Days Replacement
# 64  7 Days Replacement               In stock.  7 Days Replacement
# 65  7 Days Replacement   Only 2 left in stock.  7 Days Replacement
#
#                                                   Url
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/ASUS-15-6-inch-Integrate...
# 3   https://www.amazon.in/Dell-Inspiron-Office21-G...
# 4   https://www.amazon.in/Lenovo-IdeaPad-Warranty-...
# ..                                                ...
# 61  https://www.amazon.in/RedmiBook-Windows-15-6-i...
# 62  https://www.amazon.in/Lenovo-Ideapad-Keyboard-...
# 63  https://www.amazon.in/Lenovo-IdeaPad-39-62cm-B...
# 64  https://www.amazon.in/gp/slredirect/picassoRed...
# 65  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [66 rows x 6 columns]

# %% [markdown]
# ### 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# ### images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = "https://images.google.com/"

# %%
#Creating empty list and giving search items as list and creating loop
urls = []    
data = []
search_item = ["fruits", "cars", "Machine Learning","guitar","cakes"]
for item in search_item:
    driver.get(url)  
    time.sleep(5)
    search_bar = driver.find_element(By.TAG_NAME,"input") #Xpath for search bar
    
    search_bar.send_keys(str(item))      #sending key word for search item

# %%
 search_button =driver.find_element(By.XPATH,"//button[@class='Tg7LZd']").click() #Clicking on search button

# %%
# scrolling the web page to get more images
for _ in range(10):
    driver.execute_script("window.scrollBy(0,1)")
    imgs = driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
    img_url = []
for image in imgs:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_url.append(source)
for i in img_url[:10]:
    urls.append(i)
for i in range(len(urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response = requests.get(urls[i])
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %%
file = open(r"C:\Users\HP\fliprobogoogle"+str(i)+".jpg", "wb")

file.write(response.content)
# Out:
# 9484

# %% [markdown]
# ### 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# ### www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# ### scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# ### “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# ### details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.flipkart.com/')
#Giving input
search_item= input('Enter the name of smartphone that has to be searched : ')
# Out:
# Enter the name of smartphone that has to be searched : pixel

# %%
#Scraping search bar Xpath and clicking on search icon
search_bar = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')                                                  
search_bar.send_keys(search_item)

# %%
search_button = driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']")
search_button.click()

# %%
# Fetching urls of phones coming on 1st page
page1_urls = []
urls = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for url in urls:
    page1_urls.append(url.get_attribute("href"))

# %%
len(page1_urls)
# Out:
# 24

# %%
Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone_name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary_Camera"] = []
Smartphones["Secondary_Camera"] = []
Smartphones["Display_Size"] = []
Smartphones["Battery_Capacity"] = []
Smartphones["Price"] = []
Smartphones["URL"] = []
#  made  some  empty  list   for  the  future storage   of  scraped  data

# %%
# Scraping data from each url of page 1
for url in page1_urls:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button
    try:
        read_more = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-6a-charcoal-128-gb/p/itme5ae89135d44e?pid=MOBGFKX5YUXD74Z3&lid=LSTMOBGFKX5YUXD74Z3MXA2OB&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGFKX5YUXD74Z3.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/google-pixel-3a-clearly-white-64-gb/p/itmfgk4jfgstaack?pid=MOBFFGFPJSCEXMSG&lid=LSTMOBFFGFPJSCEXMSGODGRZE&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBFFGFPJSCEXMSG.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WU0WEW8&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVKYHCVG7W.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-2022-phantom-black-64-gb/p/itm246cc3f900c93?pid=MOBG6RGHHA2DGZZY&lid=LSTMOBG6RGHHA2DGZZYYZMW3D&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG6RGHHA2DGZZY.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZ2F9AAM8&lid=LSTMOBGDRHVZ2F9AAM8DRR9FD&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVZ2F9AAM8.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDC6HQJZKSX3K.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDC6HN5VTU6RR.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-10a-sea-blue-64-gb/p/itm755830dd54ae1?pid=MOBGDRGY2TNHJQTW&lid=LSTMOBGDRGY2TNHJQTWKK7MN2&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRGY2TNHJQTW.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-polar-black-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HZHYVX96A&lid=LSTMOBGDC6HZHYVX96AHNLOZE&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDC6HZHYVX96A.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJZZRCJ3XHG&lid=LSTMOBG7CJZZRCJ3XHG4OWCUX&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7CJZZRCJ3XHG.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7DGGNP5N2RXH&lid=LSTMOBG7DGGNP5N2RXHW6FAAI&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7DGGNP5N2RXH.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7GY6GGZ8XZGM&lid=LSTMOBG7GY6GGZ8XZGME39CNY&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7GY6GGZ8XZGM.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7H8GFGZPYUFH&lid=LSTMOBG7H8GFGZPYUFHF7NHKK&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7H8GFGZPYUFH.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHYFKQP8K&lid=LSTMOBGDRHVHYFKQP8KYHDDNN&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVHYFKQP8K.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVWJUFTYQJ&lid=LSTMOBGDRHVWJUFTYQJ7NGITG&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHVWJUFTYQJ.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHV86NZHMDM&lid=LSTMOBGDRHV86NZHMDMR0BLSS&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBGDRHV86NZHMDM.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJMHFQJFCX3&lid=LSTMOBG7CJMHFQJFCX3M7GF2X&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7CJMHFQJFCX3.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CHHZ2MUWAZ4&lid=LSTMOBG7CHHZ2MUWAZ4VNMNC8&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=1ca11b5b-19de-4344-a972-e08652bdaabb.MOBG7CHHZ2MUWAZ4.SEARCH&ppt=hp&ppn=homepage&ssid=2ny89xt2z40000001658917495925&qH=ab4086ecd47c568d

# %%
#Scraping brand name of phone data
try:
    brand_tags = driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')      
    Smartphones["Brand"].append(brand_tags.text.split()[0])
except NoSuchElementException:
    Smartphones['Brand'].append('-')
    
    
    #Scraping phone name data
try:
    name_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')     
    Smartphones['Phone_name'].append(name_tags.text)
except NoSuchElementException:
    Smartphones['Phone_name'].append('-')
    
    
    #Scraping phone color data
try:
    color_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
    Smartphones['Colour'].append(color_tags.text)
except NoSuchElementException:
    Smartphones['Colour'].append('-')
     
    
    #Scraping RAM data
try:
    ram_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
    Smartphones['RAM'].append(ram_tags.text)
except NoSuchElementException:
    Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data
try:
    rom_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
    Smartphones['Storage(ROM)'].append(rom_tags.text)
except NoSuchElementException:
    Smartphones['Storage(ROM)'].append('-')
    #Scraping Primary camera data
try:                                                                                    
    pri_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
    Smartphones['Primary_Camera'].append(pri_tags.text)
except NoSuchElementException:
    Smartphones['Primary_Camera'].append('-')

# %%
#Scraping secondary camera data
try:
    sec_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
    if sec_tags != "Secondary_Camera" :
        if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
            sec_cam = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
        else :
            raise NoSuchElementException
    else :
        sec_cam = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        Smartphones['Secondary_Camera'].append(sec_cam.text)
except NoSuchElementException:
    Smartphones['Secondary_Camera'].append('-')
     #Scraping Display size data 
try:
    disp_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/div')
    if disp_tags.text != "Display Features" : raise NoSuchElementException
    disp_size = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
    Smartphones['Display_Size'].append(disp_size.text)
except NoSuchElementException:
    Smartphones['Display_Size'].append('-')

# %%
  #Scraping battery capacity data
try:
    if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
        if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
            bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
        elif driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
            bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
        else:
            raise NoSuchElementException
    else :
        bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
        if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
        bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
    Smartphones['Battery_Capacity'].append(bat_capa.text)
except NoSuchElementException:
    Smartphones['Battery_Capacity'].append('-')
        
        
        
    #Scraping Price data
try:
    price_tags = driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')      
    Smartphones['Price'].append(price_tags.text)
except NoSuchElementException:
    Smartphones['Price'].append('-')

# %%
len(Smartphones['Brand'])
len(Smartphones['URL'])
len(Smartphones["Phone_name"])
len(Smartphones["Colour"])
len(Smartphones["RAM"])
len(Smartphones["Storage(ROM)"])
len(Smartphones["Primary_Camera"])
len(Smartphones["Secondary_Camera"])
len(Smartphones["Display_Size"])
len(Smartphones["Battery_Capacity"])
len(Smartphones["Price"])
len(Smartphones["URL"])
# Out:
# 24

# %%
df = pd.DataFrame({})
df['Brands']=Smartphones["Brand"][0:24]
df['Phonenames']=Smartphones["Phone_name"][0:24]
df['Colours']=Smartphones["Colour"][0:24]
df['RAMs']=Smartphones["RAM"][0:24]
df['Storages']=Smartphones["Storage(ROM)"][0:24]
df['Primary_cams']=Smartphones["Primary_Camera"][0:24]
df['Display_size']=Smartphones["Display_Size"][0:24]
df['Price']=Smartphones["Price"][0:24]
df['Battery_capacity']=Smartphones["Battery_Capacity"][0:24]

# %%
df
# Out:
#   Brands      Phonenames      Colours  RAMs Storages      Primary_cams  \
# 0  Redmi  Redmi 9A Sport  Coral Green  2 GB    32 GB  13MP Rear Camera
#
#            Display_size   Price Battery_capacity
# 0  16.59 cm (6.53 inch)  ₹6,819                -

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import re

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(5)

# %%
#Sending keyword for seach bar and search button
city = input('Enter City name that has to be searched : ')
search_bar = driver.find_element(By.ID,"searchboxinput")                       
search_bar.clear()                                                             
time.sleep(5)

search_bar.send_keys(city)                                                     
search_btn = driver.find_element(By.ID,"searchbox-searchbutton")              
search_btn.click()                                                             
time.sleep(5)

try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City name that has to be searched : Bengaluru
# URL Extracted:  https://www.google.co.in/maps/place/Bengaluru,+Karnataka/@12.9538477,77.3507372,10z/data=!3m1!4b1!4m5!3m4!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627
# Latitude = 12.9538477, Longitude = 77.3507372

# %% [markdown]
# ### 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# ### from trak.in.

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
Dates=[]
company=[]
Industry=[]
Investor_Name=[]
Investment_Type=[]
Amount=[]

# %%
#scraping the company name 
time.sleep(10)
companies=driver.find_elements(By.XPATH,"//td[@class='column-3']")
for i in companies:
    if len(company)>20:
            break
    else:
        if i.text is None :
            company.append("--") 
        else:
            company.append(i.text)
    
        

#scraping the Industry 
Ind=driver.find_elements(By.XPATH,"//td[@class='column-4']")
for i in Ind:
    if len(Industry)>20:
        break
    else :
        if i.text is None :
            Industry.append("--") 
        else:
            Industry.append(i.text)

#scraping the Dates 
dt=driver.find_elements(By.XPATH,"//td[@class='column-2']")
for i in dt:
    if len(Dates)>20 :
        break
    else:
        if i.text is None :
            Dates.append("--") 
        else:
            Dates.append(i.text)

#scraping the Investor_Name 
IN=driver.find_elements(By.XPATH,"//td[@class='column-7']")
for i in IN:
    if len(Investor_Name) >20:
        break
    else:
        if i.text is None :
            Investor_Name.append("--")
        else:
            Investor_Name.append(i.text)

#scraping the Investment_Type 
IT=driver.find_elements(By.XPATH,"//td[@class='column-8']")
for i in IT:
    if len(Investment_Type)>20:
        break
    else:
        if i.text is None :
            Investment_Type.append("--") 
        else:
            Investment_Type.append(i.text)

#scraping the Amount 
Price=driver.find_elements(By.XPATH,"//td[@class='column-9']")
for i in Price:
    if len(Amount)>20:
        break
    else:
        if i.text is None :
            Amount.append("--") 
        else:
            Amount.append(i.text)

# %%
df=pd.DataFrame([])
df['Company']=company
df['Industry']=Industry
df['Investor_Name']=Investor_Name
df['Amount Invested']=Amount
df['Specification']=Investment_Type
df['Dates']=Dates
df
# Out:
#         Company              Industry  \
# 0        BYJU’S              Edu-tech
# 1        Meesho            E-commerce
# 2        Swiggy  Online Food Delivery
# 3         Groww               FinTech
# 4       Beldara            E-commerce
# 5     DealShare            E-commerce
# 6      Uniphore            Technology
# 7         Dunzo            E-commerce
# 8        BYJU’S              Edu-tech
# 9   SkilloVilla              Edu-tech
# 10     CityMall            E-commerce
# 11        DotPe               FinTech
# 12     Doubtnut              Edu Tech
# 13       Zomato           Hospitality
# 14    Fingerlix           Hospitality
# 15        Zolve               FinTech
# 16    KreditBee               Finance
# 17    Pepperfry            E-commerce
# 18      Grofers            E-Commerce
# 19      Nothing            Technology
# 20  SplashLearn                EdTech
#
#                                         Investor_Name Amount Invested  \
# 0                                     Innoven Capital     460,000,000
# 1                              SoftBank Vision Fund 2     300,000,000
# 2   Amansa Holdings, Carmignac, Falcon Edge Capita...     343,000,000
# 3          MC Global Edtech, B Capital, Baron, others      83,000,000
# 4                            Hindustan Media Ventures       7,400,000
# 5                                     Innoven Capital     250,000,000
# 6                           Sorenson Capital Partners     140,000,000
# 7                           Krishtal Advisors Pte Ltd       8,000,000
# 8          MC Global Edtech, B Capital, Baron, others     460,000,000
# 9                               Titan Capital, others     300,000,000
# 10                                     Accel Partners      11,000,000
# 11                                               PayU      27,500,000
# 12  SIG Global, Sequoia Capital, WaterBridge Ventu...       2,500,000
# 13                                 Tiger Global, Kora     250,000,000
# 14           Rhodium Trust, Accel Partners and Swiggy    2,747,045.20
# 15     Accel Partners and Lightspeed Venture Partners     1,50,00,000
# 16  Azim Premji’s PremjiInvest and South Korea’s M...      75,000,000
# 17                                    InnoVen Capital       4,773,958
# 18                         SoftBank Vision Fund (SVF)      55,000,000
# 19                                                 GV      15,000,000
# 20                                       Owl Ventures      18,000,000
#
#      Specification       Dates
# 0         Series F  01/04/2021
# 1         Series E  05/04/2021
# 2         Series J  14/04/2021
# 3         Series D  07/04/2021
# 4          Venture  14/04/2021
# 5   Debt Financing  04/03/2021
# 6         Series D  31/03/2021
# 7         Series E  30/03/2021
# 8         Series F  30/03/2021
# 9             Seed  23/03/2021
# 10        Series A  25/03/2021
# 11        Series A  26/03/2021
# 12        Series B  11/02/2021
# 13         Venture  22/02/2021
# 14        Series C  19/02/2021
# 15            Seed  17/02/2021
# 16        Series C  15/02/2021
# 17  Debt Financing  12/02/2021
# 18     Unspecified  12/02/2021
# 19        Series A  09/02/2021
# 20        Series C  09/02/2021

# %% [markdown]
# ### 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
#Opening the specified url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(5)

# %%
#searching for best laptop
best_gam_lap = driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(5)

# %%
#Creating empty lists
lap_name = []
ope_sys = []
display = []
processor = []
memory = []
weight = []
graph_proc = []
price = []

# %%
# Scraping the data of laptop names
name_tags = driver.find_elements(By.XPATH,"//table[@id='summtable']//tr//td[1]")
for name in name_tags:
    lap_name.append(name.text)
    
    
#Scraping the data of operating system
try:
    os_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[5]//td[3]")
    for os in os_tags:
        ope_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display
try:
    disp_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[4]//td[3]")
    for disp in disp_tags:
        display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    pro_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[3]//td[3]")
    for pro in pro_tags:
        processor.append(pro.text)
except NoSuchElementException:
    pass


#Scraping data of memory
try:
    memo_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[6]//td[3]")
    for memo in memo_tags:
        memory.append(memo.text)
except NoSuchElementException:
    pass
#Scraping data of weight
try:
    wgt_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[8]//td[3]")
    for wgt in wgt_tags:
        weight.append(wgt.text)
except NoSuchElementException:
    pass

#Scraping data of Graph processor
try:
    gra_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[7]//td[3]")
    for gra in gra_tags:
        graph_proc.append(gra.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    pri_tags = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in pri_tags:
        price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
len(lap_name),len(ope_sys),len(display),len(processor),len(memory),len(weight),len(graph_proc),len(price)
# Out:
# (10, 10, 10, 10, 10, 10, 10, 10)

# %%
#DATA FRAMEING
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = lap_name
Gaming_Laptop['Operating system'] = ope_sys
Gaming_Laptop['Display'] = display
Gaming_Laptop['Processor'] = processor
Gaming_Laptop['Memory'] = memory
Gaming_Laptop['Weight'] = weight
Gaming_Laptop['Graphical Processor'] = graph_proc
Gaming_Laptop['Price'] = price

# %%
Gaming_Laptop
# Out:
#                                      Laptop Name Operating system  \
# 0                           MSI Titan GT77-12UHS  Windows 11 Home
# 1                               Alienware x17 R2  Windows 11 Home
# 2          Acer Predator Triton 500 SE PT516-52s  Windows 11 Home
# 3                        Omen by HP (16-B1371TX)  Windows 11 Home
# 4  Acer Predator Helios 300 AN515-45 (NH.QBRSI.0  Windows 11 Home
# 5                     MSI Delta 15 (A5EFK-083IN)  Windows 11 Home
# 6                        Omen by HP (16-c0141AX)  Windows 11 Home
# 7              Lenovo Legion 5i Pro (82RF00MGIN)  Windows 11 Home
# 8  Alienware m15 R5 Ryzen Edition icc-c780001win  Windows 11 Home
# 9               Lenovo Slim 7 Gen 6 (82K8002JIN)  Windows 11 Home
#
#                                            Display  \
# 0  17.3″ (3840 x 2160) screen, 120 Hz refresh rate
# 1    17.3″ (1920x1080) screen, 360 Hz refresh rate
# 2    16″ (2560 x 1600) screen, 240 Hz refresh rate
# 3                       16.1″ (2560 x 1440) screen
# 4  15.6″ (2560 x 1440) screen, 165 Hz refresh rate
# 5   15.6″ (1920 x 1080) screen, 240Hz refresh rate
# 6                       16.1″ (2560 x 1440) screen
# 7    16″ (2560 x 1600) screen, 165 Hz refresh rate
# 8   15.6″ (1920 x 1080) screen, 165Hz refresh rate
# 9                15.6″ screen, 165 Hz refresh rate
#
#                                            Processor  \
# 0   12th Gen Intel Core i9-12900HX 16 core processor
# 1  12th Gen Intel Core i9-12900HK 14 core process...
# 2  12th Gen Intel Core i7-12700H 14 core processo...
# 3  12th Gen Intel Core i7-12700H 14 core processo...
# 4                AMD Ryzen 9-5900HX 8 core processor
# 5  AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 6  AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 7  12th Gen Intel Core i7-12700H 14 core processo...
# 8  AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 9  Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
#
#                         Memory  \
# 0    64 GB DDR5 RAM & 2 TB SSD
# 1    32 GB DDR5 RAM & 1 TB SSD
# 2    32 GB DDR5 RAM & 2 TB SSD
# 3     8 GB DDR5 RAM & 1 TB SSD
# 4  16 GB DDR4 RAM & 512 GB SSD
# 5    16 GB DDR4 RAM & 1 TB SSD
# 6   16 GB DDR4 RAM & 1 TB NVMe
# 7    16 GB DDR5 RAM & 1 TB SSD
# 8  16 GB DDR4 RAM & 512 GB SSD
# 9    16 GB DDR4 RAM & 1 TB SSD
#
#                                               Weight  \
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight
# 1  399.23 x 299.57 x 14.75 mm dimension & 3.02 kg...
# 2      358 x 262 x 19.9 mm dimension & 2.4 kg weight
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight
# 7  359.9 x 264.4 x 19.9 mm dimension & 2.5 kg weight
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight
#
#                                  Graphical Processor        Price
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...          N/A
# 1  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti, Graphic...  Rs  389,990
# 2  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...  Rs  300,000
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  170,990
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  172,999
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card  Rs  188,990
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card  Rs  129,899
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  230,890
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  144,990
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card  Rs  142,990

# %% [markdown]
# ### 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# ### scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.forbes.com/billionaires/"
driver.get(url)

# %%
#Scraping Rank
rank = []
Rank = driver.find_elements(By.XPATH,"//div[@class='rank']")
for i in Rank:
    rank.append(i.text)

# %%
# Scraping Name
Name=[]
name=driver.find_elements(By.XPATH,"//div[@class='personName']")
for i in name:
    Name.append(i.text)

# %%
# Scraping Net Worth
net_worth=[]    
Net_worth=driver.find_elements(By.XPATH,"//div[@class='netWorth']")
for i in Net_worth:
    net_worth.append(i.text)

# %%
# Scraping Age
age=[]
Age=driver.find_elements(By.XPATH,"//div[@class='age']")
for i in Age:
    age.append(i.text)

# %%
# Scraping Country
country=[]
Country=driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
for i in Country:
    country.append(i.text)

# %%
# Scraping Source
source=[]
Source=driver.find_elements(By.XPATH,"//div[@class='source']")
for i in Source:
    source.append(i.text)

# %%
# Scraping industry
industry=[]
Industry=driver.find_elements(By.XPATH,"//div[@class='category']")
for i in Industry:
    industry.append(i.text)

# %%
df=pd.DataFrame({})
df['Rank']=rank
df['Name']=Name
df['Age']=age
df['Net Worth']=net_worth
df['Country']=country
df['Source']=source
df['Industry']=industry
df.head(10)
# Out:
#   Rank                      Name Age Net Worth        Country  \
# 0   1.                 Elon Musk  50    $219 B  United States
# 1   2.                Jeff Bezos  58    $171 B  United States
# 2   3.  Bernard Arnault & family  73    $158 B         France
# 3   4.                Bill Gates  66    $129 B  United States
# 4   5.            Warren Buffett  91    $118 B  United States
# 5   6.                Larry Page  49    $111 B  United States
# 6   7.               Sergey Brin  48    $107 B  United States
# 7   8.             Larry Ellison  77    $106 B  United States
# 8   9.             Steve Ballmer  66   $91.4 B  United States
# 9  10.             Mukesh Ambani  64   $90.7 B          India
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments
# 5              Google             Technology
# 6              Google             Technology
# 7            software             Technology
# 8           Microsoft             Technology
# 9         diversified            Diversified

# %% [markdown]
# ### 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# ### from any YouTube Video.

# %%
url = input('Enter Youtube video URL:')
# Out:
# Enter Youtube video URL:https://www.youtube.com/watch?v=rsHq4NPDEs0

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
i=0
while(i<100):
    driver.execute_script("window.scrollBy(0,500)") # scroll down to get more comments
    i+=1
while(i<402):
    driver.execute_script("window.scrollBy(0,5000)") # scroll down to get more comments
    i+=1
#  here   we  are  using  the  method   of  scroll  down so  that  the  500  comments  can be  automated  then and  
# there

# %%
cmt = []
upvt = []
cmttime = []
#  creating  the  empty  list  for   the  storage

# %%
cmt_tag = driver.find_elements(By.XPATH,"//*[@id='content-text']")
for i in cmt_tag:
    cmt.append(i.text.replace("\n",''))

upvt_tag = driver.find_elements(By.XPATH,"//*[@id='vote-count-middle']")
for j in upvt_tag:
    try: 
        upvt.append(j.text)
    except:
        upvt.append('-')
cmttime_tag = driver.find_elements(By.XPATH,"//*[@id='header-author']/yt-formatted-string/a")
for k in cmttime_tag:
    try: 
        cmttime.append(k.text)
    except:
        cmttime.append('-')

# %%
len(upvt)
# Out:
# 20

# %%
len(cmt)
# Out:
# 20

# %%
len(cmttime)
# Out:
# 20

# %%
for i in range(0,len(upvt)):
    if upvt[i] == '': 
        upvt[i] = '-' # replacing empty string with '-'

# %%
Youtube = {'Comment':cmt,'Commented':cmttime,'Number of upvotes':upvt}

# %%
YoutubeDF = pd.DataFrame(Youtube)
YoutubeDF
# Out:
#                                               Comment              Commented  \
# 0   Try Redis Enterprise free for life or use TIGE...              1 day ago
# 1   Salute To You Brother. I stared learning progr...              1 day ago
# 2   Thank you for these videos please make videos ...         11 minutes ago
# 3   Hello sir, make one course on Database managem...            4 hours ago
# 4                           The intro is really good               1 day ago
# 5   Hi Harry bhai, we are using this in our compan...           12 hours ago
# 6                Harry bhai you are the hero we need               1 day ago
# 7    After watching I  will definitely want to learn            12 hours ago
# 8   Harry bro could you tell me which command we u...            2 hours ago
# 9   Harry Bhaiya Over view mai tho maza aaya. I ho...              1 day ago
# 10        Teach golang bro eagerly waiting for that ️            6 hours ago
# 11  How do I become a Full Stack Developer? Which ...            5 hours ago
# 12          Bro please make tutorials on SQL language              1 day ago
# 13                  I very impressed from you ️#Harry              1 day ago
# 14                       Bro Thanks for your Content️            7 hours ago
# 15                      Congratulations on 3 million.              1 day ago
# 16  Harry bhai is doing alot of sponsorships these...  23 hours ago (edited)
# 17                    Please make playlist on node js              1 day ago
# 18                            #Harrybhi is The Best ️              1 day ago
# 19      Sir please make full video tutorials on redis           22 hours ago
#
#    Number of upvotes
# 0                 15
# 1                  5
# 2                  -
# 3                  2
# 4                  9
# 5                  2
# 6                  5
# 7                  -
# 8                  -
# 9                  2
# 10                 1
# 11                 -
# 12                 9
# 13                 -
# 14                 1
# 15                 -
# 16                 3
# 17                 5
# 18                 -
# 19                 3

# %% [markdown]
# ### 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# ### “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# ### overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
# Opening the homepage of hostelworld.com
url = "https://www.hostelworld.com/"
driver.get(url)

# %%
#locating the location search bar
search_loc = driver.find_element(By.XPATH,'//*[@id="search-input-field"]')
search_loc.send_keys("London")
time.sleep(5)

# %%
place = driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]')
place.click()

# %%
#click in search button
search_btn = driver.find_element(By.ID,'search-button')
search_btn.click()

# %%
# Make empty lists
Hostel_Name = []
Distance = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(5)
        
    # Distance from city
    distance = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for d in distance:
        Distance.append(d.text)
    time.sleep(5)
        
    #Review    
    review = driver.find_elements(By.XPATH,'//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(5)
    
    # Total number of reviews     
    t_review = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
    for t in t_review:
        total_reviews.append(t.text)
    time.sleep(5)
    
    # facilities
    service = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(5)
    
    # Prices    
    prices = driver.find_elements(By.XPATH,'//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(5)    
    try:
        next_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
time.sleep(5) 

# Separate  Privates_From price  and  Dorms_From price
private = []
for i in range(0,len(price),2):
    private.append(price[i])
time.sleep(5)

dorms = []
for i in range(1,len(price),2):
    dorms.append(price[i])

# %%
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(5)    
        
    try:
        next_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-prev"]')
        next_button.click()
    except:
        break
        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(5)
    
    # Property Description
    try:
        pd = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(5)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(5)

for i in all_text:
    Rating.append(i[0])

# %%
#creating dataframe
df = pd.DataFrame({'Hostel Name':Hostel_Name,
                'Distance from city centre':Distance,
                'Overall Review':overall_review[3:],
                'Total Reviews':total_reviews,
                'Facilities':facilities,
                'Privates From Price':private,
                'Dorms From Price':dorms,
                'Rating':Rating,
                'Property Description':property_description})
df
# Out:
#                                 Hostel Name         Distance from city centre  \
# 0                             Selina Camden   Hostel - 5.5km from city centre
# 1             Palmers Lodge - Swiss Cottage   Hostel - 6.5km from city centre
# 2                  St Christopher's Village   Hostel - 1.8km from city centre
# 3                          Generator London     Hostel - 3km from city centre
# 4                      Urbany Hostel London   Hostel - 5.4km from city centre
# 5         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 6                        No.8 Seven Sisters     Hostel - 9km from city centre
# 7   Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 8      St Christopher's Inn - London Bridge   Hostel - 1.8km from city centre
# 9                            Phoenix Hostel   Hostel - 4.2km from city centre
# 10                  Queen Elizabeth Chelsea   Hostel - 5.7km from city centre
# 11                  Hostel One Notting Hill   Hostel - 5.5km from city centre
# 12             St Christopher's Hammersmith   Hostel - 7.5km from city centre
# 13                  St Christopher's Camden   Hostel - 4.3km from city centre
# 14  St Christopher's Inn - Liverpool Street   Hostel - 3.2km from city centre
# 15                   London Waterloo Hostel   Hostel - 0.7km from city centre
# 16      PubLove @ The White Ferry, Victoria   Hostel - 2.4km from city centre
# 17               St Christopher's Greenwich   Hostel - 7.6km from city centre
# 18          St Christopher's Shepherds Bush     Hostel - 7km from city centre
# 19       PubLove @ The Exmouth Arms, Euston   Hostel - 3.4km from city centre
# 20           PubLove @ The Crown, Battersea   Hostel - 4.7km from city centre
# 21                  Saint James Backpackers   Hostel - 5.5km from city centre
# 22      PubLove @ The Green Man, Paddington   Hostel - 4.3km from city centre
# 23                          Marble Arch Inn    Hotel - 3.5km from city centre
# 24                      Britannia Inn Hotel   Hotel - 14.5km from city centre
# 25                        The Backpackshack  Hostel - 10.9km from city centre
# 26                       London House Hotel    Hotel - 5.3km from city centre
# 27                            Elmwood Hotel    Hotel - 3.2km from city centre
# 28                                Kip Hotel    Hotel - 6.8km from city centre
# 29                   The London Home Hostel   Hostel - 8.2km from city centre
#
#    Overall Review        Total Reviews  \
# 0        Fabulous     33 Total Reviews
# 1        Fabulous  15481 Total Reviews
# 2        Fabulous  11380 Total Reviews
# 3       Very Good   7056 Total Reviews
# 4          Superb    410 Total Reviews
# 5       Very Good   4405 Total Reviews
# 6            Good   3817 Total Reviews
# 7            Good   1267 Total Reviews
# 8        Fabulous   3334 Total Reviews
# 9       Very Good   3673 Total Reviews
# 10           Good   3303 Total Reviews
# 11         Superb   1424 Total Reviews
# 12      Very Good   4073 Total Reviews
# 13       Fabulous   3810 Total Reviews
# 14       Fabulous    420 Total Reviews
# 15           Good   2508 Total Reviews
# 16       Fabulous    270 Total Reviews
# 17           Good   3220 Total Reviews
# 18      Very Good    699 Total Reviews
# 19      Very Good   1034 Total Reviews
# 20           Good    255 Total Reviews
# 21           Good   1815 Total Reviews
# 22      Very Good    418 Total Reviews
# 23       Fabulous    223 Total Reviews
# 24       Fabulous     22 Total Reviews
# 25       Fabulous    732 Total Reviews
# 26       Fabulous   1382 Total Reviews
# 27           Good    116 Total Reviews
# 28           Good     54 Total Reviews
# 29         Rating    258 Total Reviews
#
#                                            Facilities  \
# 0                                           Free WiFi
# 1     Free WiFi\nFollows Covid-19 sanitation guidance
# 2     Free WiFi\nFollows Covid-19 sanitation guidance
# 3     Free WiFi\nFollows Covid-19 sanitation guidance
# 4     Free WiFi\nFollows Covid-19 sanitation guidance
# 5     Free WiFi\nFollows Covid-19 sanitation guidance
# 6     Free WiFi\nFollows Covid-19 sanitation guidance
# 7                                           Free WiFi
# 8     Free WiFi\nFollows Covid-19 sanitation guidance
# 9     Free WiFi\nFollows Covid-19 sanitation guidance
# 10                                          Free WiFi
# 11                                          Free WiFi
# 12    Free WiFi\nFollows Covid-19 sanitation guidance
# 13    Free WiFi\nFollows Covid-19 sanitation guidance
# 14    Free WiFi\nFollows Covid-19 sanitation guidance
# 15    Free WiFi\nFollows Covid-19 sanitation guidance
# 16    Free WiFi\nFollows Covid-19 sanitation guidance
# 17    Free WiFi\nFollows Covid-19 sanitation guidance
# 18    Free WiFi\nFollows Covid-19 sanitation guidance
# 19    Free WiFi\nFollows Covid-19 sanitation guidance
# 20    Free WiFi\nFollows Covid-19 sanitation guidance
# 21  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 22    Free WiFi\nFollows Covid-19 sanitation guidance
# 23    Free WiFi\nFollows Covid-19 sanitation guidance
# 24  Free Breakfast\nFollows Covid-19 sanitation gu...
# 25                                          Free WiFi
# 26                                          Free WiFi
# 27
# 28                                          Free WiFi
# 29                                          Free WiFi
#
#                   Privates From Price               Dorms From Price Rating  \
# 0              Privates From\nRs34946  Dorms From\nRs11155.87 Rs9482    8.6
# 1               No Privates Available             Dorms From\nRs3736    8.8
# 2               No Privates Available   Dorms From\nRs3186.68 Rs2868    8.1
# 3              Privates From\nRs19010             Dorms From\nRs4287    7.7
# 4              Privates From\nRs19780             No Dorms Available    9.3
# 5               No Privates Available             Dorms From\nRs3715    7.0
# 6               No Privates Available             Dorms From\nRs2043    6.2
# 7               No Privates Available             Dorms From\nRs2679    6.5
# 8               No Privates Available   Dorms From\nRs3293.36 Rs2964    8.3
# 9               No Privates Available   Dorms From\nRs4377.86 Rs4159    7.6
# 10              No Privates Available             Dorms From\nRs3040    6.7
# 11             Privates From\nRs18987             No Dorms Available    9.2
# 12              No Privates Available      Dorms From\nRs2888 Rs2599    7.9
# 13              No Privates Available   Dorms From\nRs3825.66 Rs3443    8.4
# 14              No Privates Available   Dorms From\nRs3897.12 Rs3507    8.7
# 15              No Privates Available             Dorms From\nRs5919    6.3
# 16              No Privates Available             Dorms From\nRs7200    8.1
# 17              No Privates Available   Dorms From\nRs2575.44 Rs2318    6.8
# 18              No Privates Available   Dorms From\nRs2902.22 Rs2612    7.3
# 19              No Privates Available             Dorms From\nRs6624    7.0
# 20              No Privates Available   Dorms From\nRs5645.14 Rs4516    6.6
# 21  Privates From\nRs13874.69 Rs13181   Dorms From\nRs4832.29 Rs4591    6.6
# 22              No Privates Available             Dorms From\nRs6106    7.7
# 23             Privates From\nRs15643             No Dorms Available    8.3
# 24             Privates From\nRs34082             No Dorms Available    8.2
# 25              Privates From\nRs7680             Dorms From\nRs1920    8.8
# 26  Privates From\nRs30155.43 Rs21109             No Dorms Available    8.8
# 27              Privates From\nRs9441             No Dorms Available    6.1
# 28             Privates From\nRs10913             No Dorms Available    6.6
# 29              Privates From\nRs6240             Dorms From\nRs2400    3.8
#
#                                  Property Description
# 0                                      No Description
# 1   Whether you're a backpacker, flash-packer or a...
# 2   COVID 19 Policy Update.\nIn response to Corona...
# 3   Generator London is a design hotel-hostel loca...
# 4                                      No Description
# 5   Safestay at Elephant & Castle is ideal if you ...
# 6                                      No Description
# 7                                      No Description
# 8   COVID 19 Policy Update.\nIn response to Corona...
# 9                                      No Description
# 10                                     No Description
# 11                                     No Description
# 12  In response to Coronavirus (COVID-19), additio...
# 13  COVID 19 Policy Update.\nIn response to Corona...
# 14                                     No Description
# 15                                     No Description
# 16  Walk to the river, turn left, and just keep wa...
# 17  COVID 19 Policy Update.\nIn response to Corona...
# 18  COVID 19 Policy Update.\nIn response to Corona...
# 19                                     No Description
# 20                                     No Description
# 21  We are located in central London - just 5 minu...
# 22  Where it all began - PubLove was born here in ...
# 23                                     No Description
# 24                                     No Description
# 25                                     No Description
# 26                                     No Description
# 27                                     No Description
# 28                                     No Description
# 29                                     No Description

# %%
driver.close()
